# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dat = pd.read_pickle("pickle1/tags.pkl")

dat.head(5)
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %%
N = 20
df = pd.Series(np.random.randint(10,50,N), index=np.arange(1,N+1))
cmap = plt.cm.tab10
colors = cmap(np.arange(len(df)) % cmap.N)

a = dat['tag'].value_counts()[:20].plot(kind='barh', color=colors, alpha=0.9, figsize=(8,6), legend = False)
plt.xlabel("Genre")
plt.ylabel("Number of Occurences")
plt.title("Top 20 Genres by Number of Reviews")
plt.grid(True, color = "black", alpha=0.2)
plt.gca().invert_yaxis()

# %%
a.max()
# Out:
# 8330

# %%
a.dtypes
# Out:
# dtype('int64')

# %%
dat.count()
# Out:
# userId       1093360
# movieId      1093360
# tag          1093344
# timestamp    1093360
# dtype: int64

# %%
dat.nunique()
# Out:
# userId        14592
# movieId       45251
# tag           73050
# timestamp    907730
# dtype: int64
